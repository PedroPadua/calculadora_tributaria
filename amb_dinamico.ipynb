# %%
import pandas as pd
def _get_anexos_data():
        df_anexos = pd.read_excel('anexos.xls', engine= 'xlrd')
        print(df_anexos.columns.to_list())
_get_anexos_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 import pandas as pd
#       2 def _get_anexos_data():
#       3         df_anexos = pd.read_excel('anexos.xls')
#       4         print(df_anexos.columns.to_list())
# ----> 5 _get_anexos_data()
#
# Cell In[1], line 3, in _get_anexos_data()
#       2 def _get_anexos_data():
# ----> 3         df_anexos = pd.read_excel('anexos.xls')
#       4         print(df_anexos.columns.to_list())
#
# File c:\Users\ia01\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
# ...
